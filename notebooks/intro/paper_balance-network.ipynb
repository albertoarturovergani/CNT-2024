# %% [markdown]
# # Balanced network of excitatory and inhibitory neurons.
#
# An implementation of benchmarks from Brette et al. (2007) Journal of Computational Neuroscience 23: 349-398
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2638500/ (see Fig. 24).
#
# In the paper, they compared simulations from NEST and NEURON. Here, we are going to simulate the balanced network with SpiNNaker.
#
# The network is based on the COBA models of Vogels & Abbott (J. Neurosci, 2005) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6725859/ .
#
# You can look also the explicit model in the supplementary material of Brette et al. (2007) |https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2638500/#APP2

# %% [markdown]
# <img src="../extra/VA_EXC_SPIKES.png">

# %%
fileName='VA_balance-network'

# %%
try:
    import pyNN.spiNNaker as sim
except ModuleNotFoundError:
    import pyNN.brian2 as sim

from pyNN import space 
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
#import scipy
import pickle
#import pandas as pd
#import seaborn as sns
import time
import datetime
import json
import warnings
warnings.filterwarnings('ignore')
import python_utils as pu
# %matplotlib inline

savePath = f'../outputs/' # remember to create the folder if not already present (mkdir ./notebooks/outputs)
dt_string = datetime.datetime.today().isoformat() # ISO8601 ! :-)
tag = dt_string 
saveName = f'{savePath}{fileName}-{tag}'
print(saveName)
PARS={}
# Out:
# /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/scipy/__init__.py:143: UserWarning: A NumPy version >=1.19.5 and <1.27.0 is required for this version of SciPy (detected version 1.19.0)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ../outputs/VA_balance-network-2024-03-12T12:47:10.621656

# %% [markdown]
# # step0: import the simulator

# %%
import socket
try:
    import pyNN.spiNNaker as sim
except ModuleNotFoundError:
    import pyNN.brian2 as sim
    
from pyNN.random import NumpyRNG, RandomDistribution
from pyNN.utility.plotting import Figure, Panel
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import time
from pyNN import space

# %% [markdown]
# # step1: setup the simulator

# %%
dt = 1          # (ms) simulation timestep
tstop = 1000      # (ms) simulaton duration
delay = 2 # (ms) 

sim.setup(
    timestep=dt, 
    min_delay=delay, 
    max_delay=delay) # [ms] # not that the max_delay supported by SpiNNaker is timestep * 144

rngseed = 98766987
rng = NumpyRNG(seed=rngseed, parallel_safe=True)
# Out:
# 2024-03-12 12:47:10 INFO: Read cfg files: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2024-03-12 12:47:10 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/common_model_binaries : /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/model_binaries
# 2024-03-12 12:47:10 INFO: Setting time scale factor to 10.
# 2024-03-12 12:47:10 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']

# %% [markdown]
# # step2: decide the cell types and parameters

# %%
# cell type
celltype = sim.IF_cond_exp
#  Leaky integrate and fire model with fixed threshold and exponentially-decaying post-synaptic conductance.
#  http://neuralensemble.org/docs/PyNN/_modules/pyNN/standardmodels/cells.html#IF_cond_exp
    
# Cell parameters
area = 20000.     # (µm²)
tau_m = 20.       # (ms)
cm = 1.           # (µF/cm²)
g_leak = 5e-5     # (S/cm²)

E_leak = None
E_leak = -60.  # (mV)
v_thresh = -50.   # (mV)
v_reset = -60.    # (mV)
t_refrac = 5.     # (ms) (clamped at v_reset)
v_mean = -60.     # (mV) mean membrane potential, for calculating CUBA weights
tau_exc = 5.      # (ms)
tau_inh = 10.     # (ms)
Erev_exc = 0.     # (mV)
Erev_inh = -80.   # (mV)

# === Calculate derived parameters ===
area = area * 1e-8                     # convert to cm²
cm = cm * area * 1000                  # convert to nF
Rm = 1e-6 / (g_leak * area)            # membrane resistance in MΩ
assert tau_m == cm * Rm                # just to check

cell_params = {'tau_m': tau_m,
               'tau_syn_E': tau_exc,
               'tau_syn_I': tau_inh,
               'v_rest': E_leak,
               'v_reset': v_reset,
               'v_thresh': v_thresh,
               'cm': cm,
               'tau_refrac': t_refrac,
               'i_offset': 0
               }

cell_params['e_rev_E'] = Erev_exc
cell_params['e_rev_I'] = Erev_inh

print(cell_params)
# Out:
# {'tau_m': 20.0, 'tau_syn_E': 5.0, 'tau_syn_I': 10.0, 'v_rest': -60.0, 'v_reset': -60.0, 'v_thresh': -50.0, 'cm': 0.2, 'tau_refrac': 5.0, 'i_offset': 0, 'e_rev_E': 0.0, 'e_rev_I': -80.0}

# %% [markdown]
# # step3: making cell populations

# %%
n = 1500          # number of cells
r_ei = 4.0        # number of excitatory cells:number of inhibitory cells
n_exc = int(round((n * r_ei / (1 + r_ei))))  # number of excitatory cells
n_inh = n - n_exc                            # number of inhibitory cells
print("{} {}".format(n_exc, n_inh))

pops = {
    'exc': sim.Population(
                                n_exc, 
                                celltype(**cell_params), 
                                label="Excitatory_Cells"),

    'inh': sim.Population(
                                n_inh, 
                                celltype(**cell_params), 
                                label="Inhibitory_Cells")
}

pops['exc'].record(["spikes", 'v', 'gsyn_exc', 'gsyn_inh'])
pops['inh'].record(["spikes", 'v', 'gsyn_exc', 'gsyn_inh'])


uniformDistr = RandomDistribution('uniform', [v_reset, v_thresh], rng=rng)
pops['exc'].initialize(v=uniformDistr)
pops['inh'].initialize(v=uniformDistr)

#sim.set_number_of_neurons_per_core(sim.IF_cond_exp, 50)      # this will set
# 50 neurons per core
pops.keys()
# Out:
# 1200 300
# dict_keys(['exc', 'inh'])

# %% [markdown]
# # step4: define the synapse types

# %%
# Synapse parameters
Gexc = None
Ginh = None
Gexc = 4.     # (nS) #1
Ginh = 51.    # (nS) #1
w_exc = Gexc * 1e-3              # We convert conductances to uS
w_inh = Ginh * 1e-3

exc_synapses = sim.StaticSynapse(weight=w_exc, delay=delay)
inh_synapses = sim.StaticSynapse(weight=w_inh, delay=delay)

# %% [markdown]
# # step5: select the connections algorithm

# %%
pconn = 0.02      # connection probability (2%)

exc_conn = sim.FixedProbabilityConnector(pconn, rng=rng)
inh_conn = sim.FixedProbabilityConnector(pconn, rng=rng)

# %% [markdown]
# # step6: make the projections

# %%
connections = {
    
    'e2e': sim.Projection(
        pops['exc'],
        pops['exc'], 
        exc_conn, 
        receptor_type='excitatory',
        synapse_type=exc_synapses),
    
    'e2i': sim.Projection(
        pops['exc'], 
        pops['inh'], 
        exc_conn, 
        receptor_type='excitatory',
        synapse_type=exc_synapses),
    
    'i2e': sim.Projection(
        pops['inh'], 
        pops['exc'], 
        inh_conn, 
        receptor_type='inhibitory',
        synapse_type=inh_synapses),
    
    'i2i': sim.Projection(
        pops['inh'],
        pops['inh'],
        inh_conn, 
        receptor_type='inhibitory',
        synapse_type=inh_synapses)
    
        }

connections.keys()
# Out:
# dict_keys(['e2e', 'e2i', 'i2e', 'i2i'])

# %% [markdown]
# # step7: setting the thalamic stimulus

# %%
n_thalamic_cells = 20 
stim_dur = 50.    # (ms) duration of random stimulation
rate = 100.       # (Hz) frequency of the random stimulation

exc_conn = None

pops['thalamus'] = sim.Population(
    n_thalamic_cells, 
    sim.SpikeSourcePoisson(rate=rate, duration=stim_dur),
    label="expoisson")
pops['thalamus'].record("spikes")


rconn = 0.01
ext_conn = sim.FixedProbabilityConnector(rconn)

connections['ext2e'] = sim.Projection(
    pops['thalamus'], 
    pops['exc'], 
    ext_conn, 
    receptor_type='excitatory',
    synapse_type=sim.StaticSynapse(weight=0.1))

connections['ext2i'] = sim.Projection(
    pops['thalamus'], 
    pops['inh'], 
    ext_conn, 
    receptor_type='excitatory',
    synapse_type=sim.StaticSynapse(weight=0.1))

connections.keys(), pops.keys()
# Out:
# (dict_keys(['e2e', 'e2i', 'i2e', 'i2i', 'ext2e', 'ext2i']),
#  dict_keys(['exc', 'inh', 'thalamus']))

# %% [markdown]
# # step8: run simulation

# %%
tstop = 1000 # (ms)
# simulation run

tic = time.time()
sim.run(tstop)
toc = time.time() - tic
# Out:
# 2024-03-12 12:47:10 INFO: Starting execution process
# 2024-03-12 12:47:10 INFO: Simulating for 1000 1.0ms timesteps using a hardware timestep of 10000us
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:10 INFO: Time 0:00:00.012518 taken by SpynnakerSplitterSelector
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:10 INFO: Time 0:00:00.014200 taken by DelaySupportAdder
# 2024-03-12 12:47:14 INFO: Time 0:00:03.225344 taken by SpallocMaxMachineGenerator
# Preallocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:26 INFO: Time 0:00:12.524212 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:31 INFO: Time 0:00:05.252130 taken by SpYNNakerSplitterPartitioner
# Created spalloc job 407598
# 2024-03-12 12:47:31 INFO: Created spalloc job 407598
# Job has been queued by the spalloc server.
# 2024-03-12 12:47:31 INFO: Job has been queued by the spalloc server.
# Waiting for board power commands to complete.
# 2024-03-12 12:47:33 INFO: Waiting for board power commands to complete.
# 2024-03-12 12:47:42 INFO: Time 0:00:10.566092 taken by SpallocAllocator
# 2024-03-12 12:47:42 INFO: Creating transceiver for 10.11.221.97
# 2024-03-12 12:47:42 INFO: Working out if machine is booted
# 2024-03-12 12:47:46 INFO: Attempting to boot machine
# 2024-03-12 12:47:52 INFO: Found board with version [Version: SC&MP 3.4.1 at SpiNNaker:0:0:0 (built Thu Feb 11 15:36:44 2021)]
# 2024-03-12 12:47:52 INFO: Machine communication successful
# 2024-03-12 12:47:52 INFO: Detected a machine on IP address 10.11.221.97 which has 856 cores and 120.0 links
# 2024-03-12 12:47:52 INFO: Time 0:00:09.937729 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.012704 taken by PartitionerReport
# 2024-03-12 12:47:52 INFO: Time 0:00:00.000450 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.038493 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.041784 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.012038 taken by BoardChipReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.041187 taken by EdgeToNKeysMapper
# 2024-03-12 12:47:52 INFO: The time scale factor could be reduced to 4.9984
# 2024-03-12 12:47:52 INFO: Time 0:00:00.001024 taken by LocalTDMABuilder
# Placing graph vertices via spreading over an entire machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.018690 taken by SpreaderPlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ===============================2024-03-12 12:47:52 INFO: Time 0:00:00.032291 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.014800 taken by SystemMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.014210 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.079738 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2024-03-12 12:47:52 INFO: Time 0:00:00.045186 taken by NerRouteTrafficAware
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.054468 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.011426 taken by TagReport
# Getting constraints for machine graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.041438 taken by ProcessPartitionConstraints
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.025053 taken by ZonedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.016778 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:52 INFO: Time 0:00:00.038937 taken by BasicRoutingTableGenerator
# 2024-03-12 12:47:52 INFO: Time 0:00:00.001211 taken by RouterCollisionPotentialReport
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:53 INFO: Time 0:00:00.049708 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:53 INFO: Time 0:00:00.045756 taken by BufferManagerCreator
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:53 INFO: Time 0:00:00.042165 taken by SDRAMOutgoingPartitionAllocator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:53 INFO: Time 0:00:00.369092 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:53 INFO: Time 0:00:00.034698 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:53 INFO: Time 0:00:00.046698 taken by GraphBinaryGatherer
# Running pair routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
#
# 2024-03-12 12:47:57 INFO: Time 0:00:03.430307 taken by PairOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:57 INFO: Time 0:00:00.017960 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:57 INFO: Time 0:00:00.051128 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:47:58 INFO: Time 0:00:01.094576 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:03 INFO: Time 0:00:05.761874 taken by LoadSystemExecutableImages
# 2024-03-12 12:48:03 INFO: Time 0:00:00.002371 taken by TagsFromMachineReport
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:04 INFO: Time 0:00:00.028196 taken by TagsLoader
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:05 INFO: Time 0:00:01.110374 taken by HostExecuteApplicationDataSpecification
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2024-03-12 12:48:09 INFO: Time 0:00:04.168441 taken by SynapseExpander
# Running bitfield generation on chip
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2024-03-12 12:48:12 INFO: Time 0:00:03.365888 taken by OnChipBitFieldGenerator
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:12 INFO: Time 0:00:00.041649 taken by FinishConnectionHolders
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:12 INFO: Time 0:00:00.128488 taken by ReadRoutingTablesFromMachine
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:12 INFO: Time 0:00:00.016672 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:12 INFO: Time 0:00:00.015541 taken by comparisonOfRoutingTablesReport
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:12 INFO: Time 0:00:00.037868 taken by CompressedRouterSummaryReport
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:12 INFO: Time 0:00:00.016066 taken by RoutingTableFromMachineReport
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:12 INFO: Time 0:00:00.047290 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:19 INFO: Time 0:00:06.977766 taken by LoadApplicationExecutableImages
# 2024-03-12 12:48:19 INFO: Running for 1 steps for a total of 1000.0ms
# 2024-03-12 12:48:19 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:20 INFO: Time 0:00:00.086160 taken by SdramUsageReportPerChip
# 2024-03-12 12:48:20 INFO: creating live event connection database in /home/bbpnrsoa/CNT-2024/notebooks/reports/2024-03-12-12-47-10-698885/run_1/input_output_database.db
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:20 INFO: Time 0:00:00.078343 taken by DatabaseInterface
# 2024-03-12 12:48:20 INFO: ** Notifying external sources that the database is ready for reading **
# 2024-03-12 12:48:20 INFO: Time 0:00:00.001015 taken by CreateNotificationProtocol
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:20 INFO: Time 0:00:00.114617 taken by GraphProvenanceGatherer
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:20 INFO: Time 0:00:00.048588 taken by ChipRuntimeUpdater
# 2024-03-12 12:48:20 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:20 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-03-12 12:48:20 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2024-03-12 12:48:20 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-03-12 12:48:20 INFO: Application started; waiting 10.1s for it to stop
# 2024-03-12 12:48:30 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2024-03-12 12:48:30 INFO: Time 0:00:10.226472 taken by ApplicationRunner
# Extracting IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:30 INFO: Time 0:00:00.050564 taken by ChipIOBufExtractor
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:30 INFO: Time 0:00:00.015570 taken by ChipIOBufClearer
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
#
# 2024-03-12 12:48:37 INFO: Time 0:00:06.563271 taken by BufferExtractor
# 2024-03-12 12:48:37 INFO: Time 0:00:00.000135 taken by FinaliseTimingData
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:37 INFO: Time 0:00:00.060445 taken by PlacementsProvenanceGatherer
# 2024-03-12 12:48:37 INFO: Time 0:00:00.001082 taken by RedundantPacketCountReport
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:37 INFO: Time 0:00:00.069260 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2024-03-12 12:48:37 INFO: Time 0:00:00.052194 taken by ProfileDataGatherer

# %%
print(toc)
# Out:
# 86.60723757743835

# %% [markdown]
# # step9: save results

# %%
stateVars = {}
for pop in pops.keys():
    for recording in ['v', 'gsyn_inh', 'gsyn_exc', 'spikes']:
        pops[pop].write_data(f'{saveName}-{recording}.pkl')
        stateVars[pop]=pops[pop].get_data()
# Out:
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for expoisson
# |0%                          50%                         100%|
#  ============================================================

# %% [markdown]
# # step10: recover results

# %%
stateVars.keys()
results = pu.recover_results(stateVars)
results.keys()
# Out:
# exc
# v
# gsyn_exc
# gsyn_inh
# inh
# v
# gsyn_exc
# gsyn_inh
# thalamus
# dict_keys([('exc', 'v'), ('exc', 'gsyn_exc'), ('exc', 'gsyn_inh'), ('exc', 'spikes'), ('inh', 'v'), ('inh', 'gsyn_exc'), ('inh', 'gsyn_inh'), ('inh', 'spikes'), ('thalamus', 'spikes')])

# %% [markdown]
# # step11: postprocessing (looking at the results)

# %%
from pyNN.utility.plotting import Figure, Panel

Figure(
    # raster plot of the presynaptic neuron spike times
    Panel(stateVars['exc'].segments[0].spiketrains, 
          xlabel="Time/ms", xticks=True,
          yticks=True, markersize=0.2, xlim=(0, tstop)),
    title="Vogels-Abbott benchmark: excitatory cells spikes")

# %%
### from pyNN.utility.plotting import Figure, Panel

Figure(
    # raster plot of the presynaptic neuron spike times
    Panel(stateVars['exc'].segments[0].spiketrains, xlabel="Time (ms)", xticks=True,
          yticks=True, markersize=0.2, xlim=(0, tstop)),
    title="Vogels-Abbott benchmark: inhibitory cells spikes")

# %%
# classic matplotlib rasterplot function

fig, ax = plt.subplots(2,1, sharex=True, figsize=(9,5))
p0=ax[0].eventplot(results['exc', 'spikes'], color='green')
p1=ax[1].eventplot(results['inh', 'spikes'], color='red')
[ax[i].set_xlabel('Time (ms)', fontsize=14) for i in [0,1]]
[ax[i].set_ylabel(feat, fontsize=14) for i, feat in enumerate(['Excitatory cells', 'Inhibitory cells'])]
# Out:
# [Text(0, 0.5, 'Excitatory cells'), Text(0, 0.5, 'Inhibitory cells')]

# %%
# check spikes

spike_rate = {
    'exc': pops['exc'].get_spike_counts(),
    'inh': pops['inh'].get_spike_counts()
}

idx=50
pop = 'exc'
print(pop + ' cell ' + str(idx) + ' :', spike_rate[pop][idx], 'spikes/' + str(tstop) + 'ms')
# Out:
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# exc cell 50 : 85 spikes/1000ms

# %%
# check conductances and membrane voltage potentials

import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,3,figsize=(11,4), sharey=True, sharex=False)
ax = ax.flatten()
p=ax[0].hist(np.asarray(results['exc', 'v']).ravel(), 100, label='exc', log=False)
p=ax[1].hist(np.asarray(results['exc', 'gsyn_exc']).ravel(), 100, label='exc')
p=ax[2].hist(np.asarray(results['exc', 'gsyn_inh']).ravel(), 100, label='exc')

p=ax[0].hist(np.asarray(results['inh', 'v']).ravel(), 100, label='inh')
p=ax[1].hist(np.asarray(results['inh', 'gsyn_exc']).ravel(), 100, label='inh')
p=ax[2].hist(np.asarray(results['inh', 'gsyn_inh']).ravel(), 100, label='inh')

ax[0].set_xlim(-90,-40)
ax[1].set_xlim(0,0.2)
ax[2].set_xlim(0,0.5)

[ax[i].legend() for i in [0,1,2]]

[ax[i].set_ylabel('excitatory cells', fontsize=14) for i in [0,1]]
ax[2].set_ylabel('inhibitory cells', fontsize=14)
[ax[idx].set_xlabel(feat, fontsize=14) for idx, feat in enumerate(['membrane potential [mV]', 'gsyn_exc [uS]', 'gsyn_inh [uS]'])]
# Out:
# [Text(0.5, 0, 'membrane potential [mV]'),
#  Text(0.5, 0, 'gsyn_exc [uS]'),
#  Text(0.5, 0, 'gsyn_inh [uS]')]

# %%
# voltage in excitatory pop

fig, ax = plt.subplots(1,3, figsize=(13,4), sharey=True, sharex=True)
ax = ax.flatten()

p = {}
for idx, feat in enumerate(['v', 'gsyn_exc', 'gsyn_inh']):
    p[idx] = ax[idx].imshow(np.asarray(results['exc', feat]).T,  norm=colors.PowerNorm(gamma= 0.75))

[fig.colorbar(p[idx], ax=ax[idx], shrink=0.5) for idx in [0,1,2]]

[ax[i].set_xlabel('time [ms]', fontsize=14) for i in [0,1,2]]
[ax[i].set_ylabel('excitatory cells', fontsize=14) for i in [0,1,2]]
[ax[idx].set_title(feat, fontsize=14) for idx, feat in enumerate(['membrane potential [mV]', 'gsyn_exc [uS]', 'gsyn_inh [uS]'])]

p.keys()
# Out:
# dict_keys([0, 1, 2])

# %%
# voltage in inhibitory pop

fig, ax = plt.subplots(3,1, figsize=(11,11), sharey=True, sharex=False)
ax = ax.flatten()

p = {}
for idx, feat in enumerate(['v', 'gsyn_exc', 'gsyn_inh']):
    p[idx] = ax[idx].imshow(np.asarray(results['inh', feat]).T,  norm=colors.PowerNorm(gamma= 0.75))

[fig.colorbar(p[idx], ax=ax[idx], shrink=0.6) for idx in [0,1,2]]

[ax[i].set_xlabel('time [ms]', fontsize=14) for i in [0,1,2]]
[ax[i].set_ylabel('inhibitory cells', fontsize=14) for i in [0,1,2]]
[ax[idx].set_title(feat, fontsize=14) for idx, feat in enumerate(['membrane potential [mV]', 'gsyn_exc [uS]', 'gsyn_inh [uS]'])]

rasterplot=False
if rasterplot:
    for i in [0,1,2]:
        ax[i].eventplot(results['inh', 'spikes'])

# %%
# signal processing step, statistics, information theory tools, etc

# %% [markdown]
# # step12: close simulation

# %%
# if you run it, you cannot reload some cells, but it is needed to restart the overall simulation

sim.end()
# Out:
# 2024-03-12 12:48:52 WARNING: The extra monitor on 3, 3 has detected that 11 packets were dumped from a core failing to take the packet. This often occurs when the executable has crashed or has not been given a multicast packet callback. It can also result from the core taking too long to process each packet. These packets were reinjected and so this number is likely a overestimate.
# 2024-03-12 12:48:52 WARNING: The extra monitor on 4, 4 has detected that 4 packets were dumped from a core failing to take the packet. This often occurs when the executable has crashed or has not been given a multicast packet callback. It can also result from the core taking too long to process each packet. These packets were reinjected and so this number is likely a overestimate.
# 2024-03-12 12:48:52 WARNING: The extra monitor on 4, 5 has detected that 1 packets were dumped from a core failing to take the packet. This often occurs when the executable has crashed or has not been given a multicast packet callback. It can also result from the core taking too long to process each packet. These packets were reinjected and so this number is likely a overestimate.
# 2024-03-12 12:48:52 WARNING: The extra monitor on 5, 4 has detected that 9 packets were dumped from a core failing to take the packet. This often occurs when the executable has crashed or has not been given a multicast packet callback. It can also result from the core taking too long to process each packet. These packets were reinjected and so this number is likely a overestimate.

# %% [markdown]
# ## Task 1: on the self sustained acitivity conditions
#
# - in the image below, the panel a) shows the sustained activity conditions of the network. <br>
#   Try different set of weights combinations for discovering different functional network configurations

# %% [markdown]
# <img src="../extra/VA_EXC_BALANCE.png">

# %% [markdown]
# - image taken from Vogels & Abbott (J. Neurosci, 2005) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6725859/,
